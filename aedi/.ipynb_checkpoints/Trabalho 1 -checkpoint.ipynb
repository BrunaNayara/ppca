# %% [markdown]
# # Distribuição normal
#
# Descrever o que é e a fórmula

# %%
# Calcular a função densidade de probabilidade

def densidade_prob(x, media, desv_pad):
    dp = (np.pi*desv_pad) * np.exp(-0.5*((x-media)/desv_pad)**2)
    return dp

# %%
# Plotar o gráfico

def grafico(x, pdf):
    plt.plot(x,pdf , color = 'red')
    plt.xlabel('Data points')
    plt.ylabel('Probability Density')

# %%
media = 50
desvio = 10
lb = 20
up = 80
x = x = np.linspace(lb,up)
pdf = densidade_prob(x, media, desvio)
print(pdf)


plt.plot(x, pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# [ 0.34899942  0.50015614  0.70611395  0.98204702  1.34548254  1.81598454
#   2.41454066  3.16260676  4.08078922  5.1871813   6.49541625  8.01255169
#   9.73695126 11.65637322 13.74650165 15.97015859 18.27740625 20.60668807
#  22.88706617 25.04150055 26.99099343 28.65930706 29.97787177 30.89044792
#  31.35710135 31.35710135 30.89044792 29.97787177 28.65930706 26.99099343
#  25.04150055 22.88706617 20.60668807 18.27740625 15.97015859 13.74650165
#  11.65637322  9.73695126  8.01255169  6.49541625  5.1871813   4.08078922
#   3.16260676  2.41454066  1.81598454  1.34548254  0.98204702  0.70611395
#   0.50015614  0.34899942]
# Text(0, 0.5, 'Probability Density')

# %%
# Importing required libraries
 
import numpy as np
import matplotlib.pyplot as plt
 
# Creating a series of data of in range of 1-50.
# x = np.linspace(1,50,200)
 
#Creating a Function.
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density
 
#Calculate mean and Standard deviation.
#mean = np.mean(x)
#sd = np.std(x)

mean = 50
sd = 10

    
#Apply function to the data.
pdf = normal_dist(x,mean,sd)
 
#Plotting the Results
plt.plot(x,pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

mean = 100
sd = 15

lb = 80
ub = 120
    
# Creating the distribution
data = np.arange(40,150,1)
pdf = norm.pdf(data , loc = mean , scale = sd )
print(pdf)

p_ub = norm(loc = mean , scale = sd).cdf(ub)
p_lb = norm(loc = mean , scale = sd).cdf(lb)

print(p_ub)
print(p_lb)

prob = p_ub - p_lb

print(prob)

#Visualizing the distribution
sb.set_style('whitegrid')
sb.lineplot(data, pdf , color = 'black')
plt.xlabel('Heights')
plt.ylabel('Probability Density')
# Out:
# [8.92201505e-06 1.16227719e-05 1.50739226e-05 1.94631284e-05
#  2.50189349e-05 3.20180434e-05 4.07934620e-05 5.17435404e-05
#  6.53418641e-05 8.21479446e-05 1.02818600e-04 1.28119865e-04
#  1.58939213e-04 1.96297808e-04 2.41362415e-04 2.95456561e-04
#  3.60070412e-04 4.36868806e-04 5.27696772e-04 6.34581844e-04
#  7.59732402e-04 9.05531282e-04 1.07452387e-03 1.26939997e-03
#  1.49296869e-03 1.74812594e-03 2.03781398e-03 2.36497286e-03
#  2.73248374e-03 3.14310445e-03 3.59939777e-03 4.10365342e-03
#  4.65780507e-03 5.26334389e-03 5.92123074e-03 6.63180925e-03
#  7.39472231e-03 8.20883480e-03 9.07216549e-03 9.98183104e-03
#  1.09340050e-02 1.19238944e-02 1.29457370e-02 1.39928197e-02
#  1.50575218e-02 1.61313816e-02 1.72051884e-02 1.82690978e-02
#  1.93127702e-02 2.03255285e-02 2.12965337e-02 2.22149735e-02
#  2.30702595e-02 2.38522286e-02 2.45513427e-02 2.51588818e-02
#  2.56671250e-02 2.60695129e-02 2.63607894e-02 2.65371151e-02
#  2.65961520e-02 2.65371151e-02 2.63607894e-02 2.60695129e-02
#  2.56671250e-02 2.51588818e-02 2.45513427e-02 2.38522286e-02
#  2.30702595e-02 2.22149735e-02 2.12965337e-02 2.03255285e-02
#  1.93127702e-02 1.82690978e-02 1.72051884e-02 1.61313816e-02
#  1.50575218e-02 1.39928197e-02 1.29457370e-02 1.19238944e-02
#  1.09340050e-02 9.98183104e-03 9.07216549e-03 8.20883480e-03
#  7.39472231e-03 6.63180925e-03 5.92123074e-03 5.26334389e-03
#  4.65780507e-03 4.10365342e-03 3.59939777e-03 3.14310445e-03
#  2.73248374e-03 2.36497286e-03 2.03781398e-03 1.74812594e-03
#  1.49296869e-03 1.26939997e-03 1.07452387e-03 9.05531282e-04
#  7.59732402e-04 6.34581844e-04 5.27696772e-04 4.36868806e-04
#  3.60070412e-04 2.95456561e-04 2.41362415e-04 1.96297808e-04
#  1.58939213e-04 1.28119865e-04]
# 0.9087887802741321
# 0.09121121972586788
# 0.8175775605482642
# /Users/bruna.moreira/.pyenv/versions/3.8.6/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Probability Density')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8g/cv_s6rq93fx1sgn6pf8p70j80000gn/T/ipykernel_39197/214598905.py in <module>
# ----> 1 pdf.cdf(80)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cdf'

# %% [markdown]
# # Distribuição normal
# Descrever o que é e a fórmula

# %%
# Importar as bibliotecas importantes
from scipy.stats import norm                          # distribuição normal
import numpy as np                                    # gerar um intervalo
import matplotlib.pyplot as plt                       # plotar o gráfico
#import seaborn as sb                                  # configuração do gráfico

# %%
def gerar_intervalo(inicio, final, passo):
    """
    Essa função usa a função arange do numpy para gerar um intervalo
    """
    return np.arange(inicio, final, passo)

# %%
def densidade_probabilidade(dados, media, desvio_padrao):
    """
    Essa função retorna a função densidade de probabilidade
    """
    return norm.pdf(dados , loc = media , scale = desvio_padrao)

# %%
def probabilidade_acumulada(media, desvio_padrao, ponto):
    """
    Essa função retorna a probabilidade acumulada
    """
    return norm(loc = media , scale = desvio_padrao).cdf(ponto)

# %%
# declarando os valores
media = 100
desvio_padrao = 15

limite_inferior = 80
limite_superior = 120

inicio_grafico = 50
final_grafico = 150

# %%
# densidade de probabilidade
dados = gerar_intervalo(inicio_grafico, final_grafico, 1)
pdf = densidade_probabilidade(dados, media, desvio_padrao)

# calcular probabilidade acumulada
prob_superior = probabilidade_acumulada(media, desvio_padrao, limite_superior)
prob_inferior = probabilidade_acumulada(media, desvio_padrao, limite_inferior)

# %%
print(prob_superior)
print(prob_inferior)
# Out:
# 0.9087887802741321
# 0.09121121972586788

# %%
probabilidade_intervalo = prob_superior - prob_inferior
print(probabilidade_intervalo)
# Out:
# 0.8175775605482642

# %%
plt.plot(dados, pdf , color = 'red')
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')
